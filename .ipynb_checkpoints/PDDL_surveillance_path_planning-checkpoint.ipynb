# %% [markdown]
# #### The code is expanding the work available in: https://github.com/pucrs-automated-planning/pddl-parser , and; Specific snippets (for heuristics and informed (Dijkstra, A*, Greedy Best First) and uninformed (DFS, BFS) search algorithms) can be also mutated from: https://github.com/APLA-Toolbox/PythonPDDL

# %% [markdown]
# #### Check URL: https://github.com/remykarem/py2pddl for dynamic PDDL-based planning (Dynamic Python to Dynamic PDDL regeneration)

# %%
### Install a pip package (e.g., numpy) in the current Jupyter kernel
#import sys
#!{sys.executable} -m pip install numpy

# %% [markdown]
# ## PDDL Parser (only):

# %%
## running the PDDL.py main file from the terminal using python
#!python PDDL.py # examples/dwr/dwr.pddl examples/dwr/pb1.pddl

# %% [markdown]
# ## PDDL Planner (baseline BFS planner):

# %%
#!python -B planner.py examples/dinner/dinner.pddl examples/dinner/pb1.pddl -v

# %%
def pause(variable): # function to pause and print values in the console 
    print("********************************")
    print(f"Debug: \n{variable}\n")
    wait = input("Press Enter to continue!")
    print("********************************")

# %%
def validate_conditions(state, positive, negative): # function to validate if positive and negative conditions are valid at a given state
        return positive.issubset(state) and negative.isdisjoint(state)

# %%
def state_transition(state, positive, negative): # function to apply the transition of the state (activate positive and deactivate negative effects)
        return state.difference(negative).union(positive)

# %%
def grounding_all_actions(parser): # Grounding all actions to generate every valid instantiation 
                                   # (based on the number and types of objects defined in problem.pddl)
    
    grounded_actions = []
    for action in parser.actions:
        for act in action.groundify(parser.objects, parser.types):
            # parser.objects are all instantiated objects (e.g., crane: [a, b, c, d])
            # parser.types are all different types of instantiated objects (e.g., crane)
            grounded_actions.append(act)
            
    return grounded_actions

# %%
def applicable_actions(state, grounded_actions): # Listing  all grounded (existing) actions that are applicable
                                                 # at the current state
    
    applicable_actions = []
    for act in grounded_actions:
        positive = act.positive_preconditions
        negative = act.negative_preconditions
    
        if validate_conditions(state, positive, negative):
            applicable_actions.append(act) 
    
    return applicable_actions

# %%
def solve_BFS(parser, grounded_actions):
        
        # Parsed data (all three objects are type: frozenset i.e., immutable static objects)
        state = parser.state # initial problem.pddl state
        goal_pos = parser.positive_goals # goal state positive conditions
        goal_not = parser.negative_goals # goal state negative conditions
        
        # Check if the goal state has been reached (no planning is required)
        if validate_conditions(state, goal_pos, goal_not):
            print('\nInitial state meets the goal conditions!')
            return []
                               
        # Graph Search
        closed_set = set([state]) # we already checked if the initial state is the goal state so we consider it in the closed_set
        frontier_set = [state, None] # frontier_set is a list of: [ state, (action that led to this state, plan that led to this state from the root) ]
        
        while frontier_set: # while frontier_set is not empty
            
            # implementing Breadth-First-Non-Informed-Search (BFS) where the visited/closed states set is served in FIFO manner
            # since the state under consideration is popped(0) which is the oldest of the appended 'frontier' set 'new_states'
            state = frontier_set.pop(0) # popping out (remove and assign) the first (or appended) state from the frontier_set
            plan = frontier_set.pop(0) # popping out (remove and assign) the first (or appended) plan from the frontier_set i.e., None
            
            for act in grounded_actions: # iterate over all grounded actions
                
                if validate_conditions(state, act.positive_preconditions, act.negative_preconditions): # check if the grounded action is currently applicable
                    new_state = state_transition(state, act.add_effects, act.del_effects)
                    
                    if new_state not in closed_set: # check if the new_state has not been visited/evaluated already
                        if validate_conditions(new_state, goal_pos, goal_not): # check if the new state is the goal state
                            
                            full_plan = [ act ] # initialise the full plan with the last action
                            while plan:
                                act, plan = plan # iteratively unfolding the enveloped plan and the respective sequence of actions
                                full_plan.insert(0, act) # populate the full_plan 0-position entry with the previous action i.e., the sequence of actions led to the goal state

                            return full_plan
                        
                        closed_set.add(new_state) # appending (at the end of the list) the new_state (which is not the goal state)
                        frontier_set.append(new_state) # appending (at the end of the list) the new_state (which is not the goal state)
                        frontier_set.append((act, plan)) # appending the grounded action led to the new_state alongside with the up-to-date plan(t) = [ action(t), plan(t-1) ]
                    
        return None # return 'None' if the goal state has not been reached

# %%
def export_plan(plan, verbose = True):
    
    print('\n----------------------------')
    if type(plan) is list:
        print('Plan:')
        for act in plan:
            print(act if verbose else act.name + ' ' + ' '.join(act.parameters))
    else:
        print('No plan was found')
        exit(1)

# %%
def export_parser(parser):
    
    print('\n----------------------------')
    print('Domain name: ' + parser.domain_name)
    for act in parser.actions:
        print(act)
    print('Problem name: ' + parser.problem_name)
    print('Objects: ' + str(parser.objects))
    print('Types: ' + str(parser.types))
    print('Initial State: ' + str(parser.state))
    print('Positive goal conditions: ' + str(parser.positive_goals))
    print('Negative goal conditions: ' + str(parser.negative_goals))

# %%
def generate_plan(parser, solver='BFS'):
    import time
    #export_parser(parser)
    
    start_planner_time = time.time()
    grounded_actions = grounding_all_actions(parser)

    # Planner instantiation
    if solver == 'BFS':
        plan = solve_BFS(parser, grounded_actions)
    elif solver == 'DFS':
        print('No DFS planner found!\nProceeding with BFS!')
        plan = solve_BFS(parser)
        
    plan_time = time.time()

    #export_plan(plan)
    print('Planner Time: ' + str(plan_time-start_planner_time) + 's\n')
    
    return plan, grounded_actions

# %% [markdown]
# ## Generating the initial plan

# %%
from PDDL import PDDL_Parser
import time

all_plans = []
domain = "examples/dwr/dwr.pddl"
problem = "examples/dwr/pb1.pddl"

start_time = time.time()
# Parser instantiation
parser = PDDL_Parser()
parser.parse_domain(domain)
parser.parse_problem(problem)
parse_time = time.time()
print('Parse Time: ' + str(parse_time-start_time) + 's\n')

# Generate plan
active_plan, grounded_actions = generate_plan(parser)
all_plans.append(active_plan)
# Out:
# Parse Time: 0.0009970664978027344s
#
# Planner Time: 1.3434319496154785s

# %% [markdown]
# ## Creating a dynamic re-planning framework

# %%
# function for advancing the system state by applying 'apply_plan_steps_to_replan' of the 'plan' action sequence
def progress_system_state(parser, plan, grounded_actions, simulation_step, apply_plan_steps_to_replan=1):
    if apply_plan_steps_to_replan > len(plan):
        apply_plan_steps_to_replan = len(plan)

    if type(plan) is list:
        for step in range(0,apply_plan_steps_to_replan):
            act = plan[step] # applying the "optimal" action (according to the currently active_plan)
            # act = sample(applicable_actions(parser.state, grounded_actions),1)[0] # selecting a random (applicable) action
            
            simulation_step += 1
            
            print('\n**************************')
            print(f'Simulation Step: {simulation_step}')
            print('**************************\n')
            print('Applying Planned Action:')
            print(act)
            new_state = state_transition(parser.state, act.add_effects, act.del_effects)
            parser.state = new_state

        print('Reached State:')
        print(parser.state)
        
    return parser, simulation_step

# %%
def impose_stochastic_disturbance(parser, type_of_disturbance='fact'):
    ## iterate the solve(domain, problem) function, over the optimal plan states / actions / steps 
    ## changing different aspects of the deterministic environment evolution:
    ## e.g., assume that the plan will be applied and change anything at the 2nd node/state of the plan in order to re-plan:
    ## different initial state (consider the refined current initial state to be valid with a specific likelihood) -> use a random sampler to choose between 
                ## state_transition(state, positiveA, negativeA) and state_transition(state, positiveB, negativeB) function;
    ## different number of same type parser.objects (simulate robot failures or new grid obstacles/blockades from accidents) -> extend parser.objects entries appropriately
    ## different goals (simulate dynamically changing goal) -> extend / refine the goal_pos and goal_not conditions appropriately
    
    return parser

# %%
from random import sample

apply_steps_until_next_replan = 1 # e.g., apply applied_plan_steps_to_replan=1 step(s) of the currently active plan 
                                  # and then replan considering as an initial state the current state
number_of_replanning_attempts = 100 # e.g., number of attempts to replan after 'apply_plan_steps_to_replan'
simulation_step = 0                 # initial value for the total simulation step

number_of_replanning_attempts = min(number_of_replanning_attempts, len(active_plan)) # making sure than the replanning 
                                                                    # attempts are always less than the initial plans' length

for replans in range(number_of_replanning_attempts):
    
    if active_plan:  # if active_plan is not empty
        
        parser, simulation_step = progress_system_state(parser, active_plan, grounded_actions, simulation_step, apply_steps_until_next_replan)
        parser = impose_stochastic_disturbance(parser, 'fact')
        
        # print(f'Attempt to replan: {replans}')
        
        # replanning after applying actions from the previously generated plan
        active_plan, grounded_actions = generate_plan(parser)
        all_plans.append(active_plan) # replanning after applying actions based on the previously generated plan
# Out:
# **************************
# Simulation Step: 1
# **************************
#
# Applying Planned Action:
# action: take
#   parameters: ('k1', 'cc', 'cb', 'p1', 'l1')
#   positive_preconditions: [['on', 'cc', 'cb'], ['belong', 'k1', 'l1'], ['top', 'cc', 'p1'], ['attached', 'p1', 'l1'], ['in', 'cc', 'p1'], ['empty', 'k1']]
#   negative_preconditions: [['equal', 'cc', 'cb'], ['equal', 'cc', 'pallet']]
#   add_effects: [['top', 'cb', 'p1'], ['holding', 'k1', 'cc']]
#   del_effects: [['top', 'cc', 'p1'], ['in', 'cc', 'p1'], ['empty', 'k1'], ['on', 'cc', 'cb']]
#
# Reached State:
# frozenset({('unloaded', 'r1'), ('in', 'ce', 'q1'), ('on', 'ca', 'pallet'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('attached', 'p1', 'l1'), ('attached', 'q2', 'l2'), ('equal', 'ce', 'ce'), ('top', 'pallet', 'q2'), ('top', 'cb', 'p1'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cf', 'q1'), ('on', 'cb', 'ca'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('holding', 'k1', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('in', 'cb', 'p1'), ('empty', 'k2'), ('top', 'pallet', 'p2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('at', 'r1', 'l1'), ('belong', 'k2', 'l2'), ('equal', 'cf', 'cf'), ('in', 'cf', 'q1')})
# Planner Time: 1.0342586040496826s
#
#
# **************************
# Simulation Step: 2
# **************************
#
# Applying Planned Action:
# action: load
#   parameters: ('k1', 'r1', 'cc', 'l1')
#   positive_preconditions: [['at', 'r1', 'l1'], ['belong', 'k1', 'l1'], ['holding', 'k1', 'cc'], ['unloaded', 'r1']]
#   negative_preconditions: [['equal', 'cc', 'pallet']]
#   add_effects: [['empty', 'k1'], ['loaded', 'r1', 'cc']]
#   del_effects: [['holding', 'k1', 'cc'], ['unloaded', 'r1']]
#
# Reached State:
# frozenset({('on', 'ca', 'pallet'), ('loaded', 'r1', 'cc'), ('empty', 'k1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('attached', 'q2', 'l2'), ('equal', 'ce', 'ce'), ('at', 'r1', 'l1'), ('top', 'pallet', 'q2'), ('top', 'cb', 'p1'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cf', 'q1'), ('on', 'cb', 'ca'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('in', 'cb', 'p1'), ('empty', 'k2'), ('belong', 'k2', 'l2'), ('top', 'pallet', 'p2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('in', 'ce', 'q1'), ('equal', 'cf', 'cf'), ('in', 'cf', 'q1')})
# Planner Time: 0.8018538951873779s
#
#
# **************************
# Simulation Step: 3
# **************************
#
# Applying Planned Action:
# action: move
#   parameters: ('r1', 'l1', 'l2')
#   positive_preconditions: [['at', 'r1', 'l1'], ['adjacent', 'l1', 'l2']]
#   negative_preconditions: [['occupied', 'l2']]
#   add_effects: [['at', 'r1', 'l2'], ['occupied', 'l2']]
#   del_effects: [['at', 'r1', 'l1'], ['occupied', 'l1']]
#
# Reached State:
# frozenset({('in', 'ce', 'q1'), ('on', 'ca', 'pallet'), ('loaded', 'r1', 'cc'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('at', 'r1', 'l2'), ('attached', 'q2', 'l2'), ('equal', 'cf', 'cf'), ('equal', 'ce', 'ce'), ('top', 'pallet', 'q2'), ('top', 'cb', 'p1'), ('equal', 'pallet', 'pallet'), ('occupied', 'l2'), ('on', 'cd', 'pallet'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cf', 'q1'), ('on', 'cb', 'ca'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('in', 'cb', 'p1'), ('empty', 'k2'), ('top', 'pallet', 'p2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('belong', 'k2', 'l2'), ('empty', 'k1'), ('in', 'cf', 'q1')})
# Planner Time: 0.7370293140411377s
#
#
# **************************
# Simulation Step: 4
# **************************
#
# Applying Planned Action:
# action: unload
#   parameters: ('k2', 'r1', 'cc', 'l2')
#   positive_preconditions: [['empty', 'k2'], ['belong', 'k2', 'l2'], ['at', 'r1', 'l2'], ['loaded', 'r1', 'cc']]
#   negative_preconditions: [['equal', 'cc', 'pallet']]
#   add_effects: [['holding', 'k2', 'cc'], ['unloaded', 'r1']]
#   del_effects: [['empty', 'k2'], ['loaded', 'r1', 'cc']]
#
# Reached State:
# frozenset({('unloaded', 'r1'), ('on', 'ca', 'pallet'), ('empty', 'k1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('at', 'r1', 'l2'), ('attached', 'q2', 'l2'), ('holding', 'k2', 'cc'), ('equal', 'ce', 'ce'), ('top', 'pallet', 'q2'), ('top', 'cb', 'p1'), ('equal', 'pallet', 'pallet'), ('occupied', 'l2'), ('on', 'cd', 'pallet'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cf', 'q1'), ('on', 'cb', 'ca'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('in', 'cb', 'p1'), ('belong', 'k2', 'l2'), ('top', 'pallet', 'p2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('in', 'ce', 'q1'), ('equal', 'cf', 'cf'), ('in', 'cf', 'q1')})
# Planner Time: 0.5106279850006104s
#
#
# **************************
# Simulation Step: 5
# **************************
#
# Applying Planned Action:
# action: move
#   parameters: ('r1', 'l2', 'l1')
#   positive_preconditions: [['adjacent', 'l2', 'l1'], ['at', 'r1', 'l2']]
#   negative_preconditions: [['occupied', 'l1']]
#   add_effects: [['at', 'r1', 'l1'], ['occupied', 'l1']]
#   del_effects: [['at', 'r1', 'l2'], ['occupied', 'l2']]
#
# Reached State:
# frozenset({('unloaded', 'r1'), ('in', 'ce', 'q1'), ('on', 'ca', 'pallet'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('attached', 'q2', 'l2'), ('holding', 'k2', 'cc'), ('equal', 'cf', 'cf'), ('equal', 'ce', 'ce'), ('at', 'r1', 'l1'), ('top', 'pallet', 'q2'), ('top', 'cb', 'p1'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cf', 'q1'), ('on', 'cb', 'ca'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('in', 'cb', 'p1'), ('top', 'pallet', 'p2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('belong', 'k2', 'l2'), ('empty', 'k1'), ('in', 'cf', 'q1')})
# Planner Time: 0.47971653938293457s
#
#
# **************************
# Simulation Step: 6
# **************************
#
# Applying Planned Action:
# action: put
#   parameters: ('k2', 'cc', 'pallet', 'p2', 'l2')
#   positive_preconditions: [['attached', 'p2', 'l2'], ['top', 'pallet', 'p2'], ['belong', 'k2', 'l2'], ['holding', 'k2', 'cc']]
#   negative_preconditions: [['equal', 'cc', 'pallet']]
#   add_effects: [['on', 'cc', 'pallet'], ['empty', 'k2'], ['top', 'cc', 'p2'], ['in', 'cc', 'p2']]
#   del_effects: [['top', 'pallet', 'p2'], ['holding', 'k2', 'cc']]
#
# Reached State:
# frozenset({('unloaded', 'r1'), ('in', 'cc', 'p2'), ('on', 'ca', 'pallet'), ('empty', 'k1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('attached', 'p1', 'l1'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('top', 'pallet', 'q2'), ('top', 'cb', 'p1'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('top', 'cf', 'q1'), ('on', 'cb', 'ca'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('in', 'cb', 'p1'), ('belong', 'k2', 'l2'), ('empty', 'k2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('at', 'r1', 'l1'), ('in', 'ce', 'q1'), ('equal', 'cf', 'cf'), ('in', 'cf', 'q1')})
# Planner Time: 0.3313713073730469s
#
#
# **************************
# Simulation Step: 7
# **************************
#
# Applying Planned Action:
# action: take
#   parameters: ('k1', 'cb', 'ca', 'p1', 'l1')
#   positive_preconditions: [['in', 'cb', 'p1'], ['on', 'cb', 'ca'], ['top', 'cb', 'p1'], ['belong', 'k1', 'l1'], ['attached', 'p1', 'l1'], ['empty', 'k1']]
#   negative_preconditions: [['equal', 'cb', 'pallet'], ['equal', 'cb', 'ca']]
#   add_effects: [['holding', 'k1', 'cb'], ['top', 'ca', 'p1']]
#   del_effects: [['on', 'cb', 'ca'], ['top', 'cb', 'p1'], ['empty', 'k1'], ['in', 'cb', 'p1']]
#
# Reached State:
# frozenset({('unloaded', 'r1'), ('in', 'cc', 'p2'), ('in', 'ce', 'q1'), ('on', 'ca', 'pallet'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('holding', 'k1', 'cb'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('at', 'r1', 'l1'), ('top', 'pallet', 'q2'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('top', 'ca', 'p1'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('empty', 'k2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('belong', 'k2', 'l2'), ('equal', 'cf', 'cf'), ('in', 'cf', 'q1')})
# Planner Time: 0.21744823455810547s
#
#
# **************************
# Simulation Step: 8
# **************************
#
# Applying Planned Action:
# action: load
#   parameters: ('k1', 'r1', 'cb', 'l1')
#   positive_preconditions: [['at', 'r1', 'l1'], ['holding', 'k1', 'cb'], ['belong', 'k1', 'l1'], ['unloaded', 'r1']]
#   negative_preconditions: [['equal', 'cb', 'pallet']]
#   add_effects: [['loaded', 'r1', 'cb'], ['empty', 'k1']]
#   del_effects: [['holding', 'k1', 'cb'], ['unloaded', 'r1']]
#
# Reached State:
# frozenset({('in', 'cc', 'p2'), ('on', 'ca', 'pallet'), ('empty', 'k1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('attached', 'p1', 'l1'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('top', 'pallet', 'q2'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('top', 'ca', 'p1'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('loaded', 'r1', 'cb'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('empty', 'k2'), ('belong', 'k2', 'l2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('at', 'r1', 'l1'), ('in', 'ce', 'q1'), ('equal', 'cf', 'cf'), ('in', 'cf', 'q1')})
# Planner Time: 0.15860414505004883s
#
#
# **************************
# Simulation Step: 9
# **************************
#
# Applying Planned Action:
# action: move
#   parameters: ('r1', 'l1', 'l2')
#   positive_preconditions: [['at', 'r1', 'l1'], ['adjacent', 'l1', 'l2']]
#   negative_preconditions: [['occupied', 'l2']]
#   add_effects: [['at', 'r1', 'l2'], ['occupied', 'l2']]
#   del_effects: [['at', 'r1', 'l1'], ['occupied', 'l1']]
#
# Reached State:
# frozenset({('in', 'cc', 'p2'), ('in', 'ce', 'q1'), ('on', 'ca', 'pallet'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('at', 'r1', 'l2'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('equal', 'cf', 'cf'), ('top', 'pallet', 'q2'), ('equal', 'pallet', 'pallet'), ('occupied', 'l2'), ('on', 'cd', 'pallet'), ('top', 'ca', 'p1'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('loaded', 'r1', 'cb'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('empty', 'k2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('belong', 'k2', 'l2'), ('empty', 'k1'), ('in', 'cf', 'q1')})
# Planner Time: 0.14760422706604004s
#
#
# **************************
# Simulation Step: 10
# **************************
#
# Applying Planned Action:
# action: unload
#   parameters: ('k2', 'r1', 'cb', 'l2')
#   positive_preconditions: [['empty', 'k2'], ['loaded', 'r1', 'cb'], ['at', 'r1', 'l2'], ['belong', 'k2', 'l2']]
#   negative_preconditions: [['equal', 'cb', 'pallet']]
#   add_effects: [['holding', 'k2', 'cb'], ['unloaded', 'r1']]
#   del_effects: [['empty', 'k2'], ['loaded', 'r1', 'cb']]
#
# Reached State:
# frozenset({('in', 'cc', 'p2'), ('unloaded', 'r1'), ('on', 'ca', 'pallet'), ('empty', 'k1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('at', 'r1', 'l2'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('top', 'pallet', 'q2'), ('equal', 'pallet', 'pallet'), ('occupied', 'l2'), ('on', 'cd', 'pallet'), ('top', 'ca', 'p1'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('belong', 'k2', 'l2'), ('holding', 'k2', 'cb'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('in', 'ce', 'q1'), ('equal', 'cf', 'cf'), ('in', 'cf', 'q1')})
# Planner Time: 0.07779073715209961s
#
#
# **************************
# Simulation Step: 11
# **************************
#
# Applying Planned Action:
# action: move
#   parameters: ('r1', 'l2', 'l1')
#   positive_preconditions: [['adjacent', 'l2', 'l1'], ['at', 'r1', 'l2']]
#   negative_preconditions: [['occupied', 'l1']]
#   add_effects: [['at', 'r1', 'l1'], ['occupied', 'l1']]
#   del_effects: [['at', 'r1', 'l2'], ['occupied', 'l2']]
#
# Reached State:
# frozenset({('in', 'cc', 'p2'), ('unloaded', 'r1'), ('in', 'ce', 'q1'), ('on', 'ca', 'pallet'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('equal', 'cf', 'cf'), ('at', 'r1', 'l1'), ('top', 'pallet', 'q2'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('top', 'ca', 'p1'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('holding', 'k2', 'cb'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('belong', 'k2', 'l2'), ('empty', 'k1'), ('in', 'cf', 'q1')})
# Planner Time: 0.06482577323913574s
#
#
# **************************
# Simulation Step: 12
# **************************
#
# Applying Planned Action:
# action: put
#   parameters: ('k2', 'cb', 'pallet', 'q2', 'l2')
#   positive_preconditions: [['holding', 'k2', 'cb'], ['top', 'pallet', 'q2'], ['belong', 'k2', 'l2'], ['attached', 'q2', 'l2']]
#   negative_preconditions: [['equal', 'cb', 'pallet']]
#   add_effects: [['on', 'cb', 'pallet'], ['empty', 'k2'], ['in', 'cb', 'q2'], ['top', 'cb', 'q2']]
#   del_effects: [['holding', 'k2', 'cb'], ['top', 'pallet', 'q2']]
#
# Reached State:
# frozenset({('on', 'cb', 'pallet'), ('in', 'cc', 'p2'), ('unloaded', 'r1'), ('on', 'ca', 'pallet'), ('empty', 'k1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('in', 'cb', 'q2'), ('attached', 'p1', 'l1'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('top', 'ca', 'p1'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('empty', 'k2'), ('belong', 'k2', 'l2'), ('top', 'cb', 'q2'), ('in', 'ca', 'p1'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('at', 'r1', 'l1'), ('in', 'ce', 'q1'), ('equal', 'cf', 'cf'), ('in', 'cf', 'q1')})
# Planner Time: 0.045871734619140625s
#
#
# **************************
# Simulation Step: 13
# **************************
#
# Applying Planned Action:
# action: take
#   parameters: ('k1', 'ca', 'pallet', 'p1', 'l1')
#   positive_preconditions: [['on', 'ca', 'pallet'], ['in', 'ca', 'p1'], ['belong', 'k1', 'l1'], ['attached', 'p1', 'l1'], ['empty', 'k1'], ['top', 'ca', 'p1']]
#   negative_preconditions: [['equal', 'ca', 'pallet']]
#   add_effects: [['holding', 'k1', 'ca'], ['top', 'pallet', 'p1']]
#   del_effects: [['on', 'ca', 'pallet'], ['empty', 'k1'], ['in', 'ca', 'p1'], ['top', 'ca', 'p1']]
#
# Reached State:
# frozenset({('on', 'cb', 'pallet'), ('in', 'cc', 'p2'), ('unloaded', 'r1'), ('in', 'ce', 'q1'), ('holding', 'k1', 'ca'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('in', 'cb', 'q2'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('at', 'r1', 'l1'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('top', 'pallet', 'p1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('empty', 'k2'), ('top', 'cb', 'q2'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('belong', 'k2', 'l2'), ('equal', 'cf', 'cf'), ('in', 'cf', 'q1')})
# Planner Time: 0.054053544998168945s
#
#
# **************************
# Simulation Step: 14
# **************************
#
# Applying Planned Action:
# action: load
#   parameters: ('k1', 'r1', 'ca', 'l1')
#   positive_preconditions: [['at', 'r1', 'l1'], ['holding', 'k1', 'ca'], ['unloaded', 'r1'], ['belong', 'k1', 'l1']]
#   negative_preconditions: [['equal', 'ca', 'pallet']]
#   add_effects: [['empty', 'k1'], ['loaded', 'r1', 'ca']]
#   del_effects: [['holding', 'k1', 'ca'], ['unloaded', 'r1']]
#
# Reached State:
# frozenset({('on', 'cb', 'pallet'), ('in', 'cc', 'p2'), ('empty', 'k1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('occupied', 'l1'), ('in', 'cb', 'q2'), ('attached', 'p1', 'l1'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('equal', 'pallet', 'pallet'), ('on', 'cd', 'pallet'), ('loaded', 'r1', 'ca'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('in', 'cf', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('empty', 'k2'), ('belong', 'k2', 'l2'), ('top', 'cb', 'q2'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('at', 'r1', 'l1'), ('in', 'ce', 'q1'), ('equal', 'cf', 'cf'), ('top', 'pallet', 'p1')})
# Planner Time: 0.027950525283813477s
#
#
# **************************
# Simulation Step: 15
# **************************
#
# Applying Planned Action:
# action: move
#   parameters: ('r1', 'l1', 'l2')
#   positive_preconditions: [['at', 'r1', 'l1'], ['adjacent', 'l1', 'l2']]
#   negative_preconditions: [['occupied', 'l2']]
#   add_effects: [['at', 'r1', 'l2'], ['occupied', 'l2']]
#   del_effects: [['at', 'r1', 'l1'], ['occupied', 'l1']]
#
# Reached State:
# frozenset({('on', 'cb', 'pallet'), ('in', 'cc', 'p2'), ('in', 'ce', 'q1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('at', 'r1', 'l2'), ('in', 'cb', 'q2'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('equal', 'cf', 'cf'), ('equal', 'pallet', 'pallet'), ('occupied', 'l2'), ('on', 'cd', 'pallet'), ('loaded', 'r1', 'ca'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('top', 'pallet', 'p1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('empty', 'k2'), ('top', 'cb', 'q2'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('belong', 'k2', 'l2'), ('empty', 'k1'), ('in', 'cf', 'q1')})
# Planner Time: 0.024928569793701172s
#
#
# **************************
# Simulation Step: 16
# **************************
#
# Applying Planned Action:
# action: unload
#   parameters: ('k2', 'r1', 'ca', 'l2')
#   positive_preconditions: [['empty', 'k2'], ['belong', 'k2', 'l2'], ['at', 'r1', 'l2'], ['loaded', 'r1', 'ca']]
#   negative_preconditions: [['equal', 'ca', 'pallet']]
#   add_effects: [['holding', 'k2', 'ca'], ['unloaded', 'r1']]
#   del_effects: [['empty', 'k2'], ['loaded', 'r1', 'ca']]
#
# Reached State:
# frozenset({('on', 'cb', 'pallet'), ('in', 'cc', 'p2'), ('unloaded', 'r1'), ('empty', 'k1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('at', 'r1', 'l2'), ('in', 'cb', 'q2'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('equal', 'pallet', 'pallet'), ('occupied', 'l2'), ('on', 'cd', 'pallet'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cc', 'p2'), ('top', 'cf', 'q1'), ('holding', 'k2', 'ca'), ('in', 'cd', 'q1'), ('in', 'cf', 'q1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('belong', 'k2', 'l2'), ('top', 'cb', 'q2'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('in', 'ce', 'q1'), ('equal', 'cf', 'cf'), ('top', 'pallet', 'p1')})
# Planner Time: 0.04390835762023926s
#
#
# **************************
# Simulation Step: 17
# **************************
#
# Applying Planned Action:
# action: put
#   parameters: ('k2', 'ca', 'cc', 'p2', 'l2')
#   positive_preconditions: [['attached', 'p2', 'l2'], ['holding', 'k2', 'ca'], ['top', 'cc', 'p2'], ['belong', 'k2', 'l2']]
#   negative_preconditions: [['equal', 'ca', 'cc'], ['equal', 'ca', 'pallet']]
#   add_effects: [['in', 'ca', 'p2'], ['top', 'ca', 'p2'], ['empty', 'k2'], ['on', 'ca', 'cc']]
#   del_effects: [['holding', 'k2', 'ca'], ['top', 'cc', 'p2']]
#
# Reached State:
# frozenset({('on', 'cb', 'pallet'), ('in', 'cc', 'p2'), ('unloaded', 'r1'), ('in', 'ce', 'q1'), ('attached', 'p2', 'l2'), ('on', 'cf', 'ce'), ('belong', 'k1', 'l1'), ('at', 'r1', 'l2'), ('in', 'cb', 'q2'), ('attached', 'q2', 'l2'), ('on', 'cc', 'pallet'), ('equal', 'ce', 'ce'), ('equal', 'cf', 'cf'), ('top', 'ca', 'p2'), ('on', 'ca', 'cc'), ('equal', 'pallet', 'pallet'), ('occupied', 'l2'), ('on', 'cd', 'pallet'), ('adjacent', 'l1', 'l2'), ('attached', 'q1', 'l1'), ('top', 'cf', 'q1'), ('in', 'cd', 'q1'), ('in', 'ca', 'p2'), ('top', 'pallet', 'p1'), ('equal', 'cc', 'cc'), ('equal', 'ca', 'ca'), ('equal', 'cd', 'cd'), ('equal', 'cb', 'cb'), ('empty', 'k2'), ('top', 'cb', 'q2'), ('on', 'ce', 'cd'), ('adjacent', 'l2', 'l1'), ('attached', 'p1', 'l1'), ('belong', 'k2', 'l2'), ('empty', 'k1'), ('in', 'cf', 'q1')})
#
# Initial state meets the goal conditions!
# Planner Time: 0.023929357528686523s
